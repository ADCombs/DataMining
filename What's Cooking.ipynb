# %% [markdown]
# <img src="https://cdn.shopify.com/s/files/1/1994/0163/products/DSC_3248_cropped_resized_93e8f56d-4e6c-4f0a-8fc4-9dff8af70de1_2048x.jpg?v=1499211925" width="500">
#
#
# #### Loading the data:

# %%
import numpy as np # This is a library that is mostly used just to create an n-dimensional array
import pandas as pd # This library uses numpy, and handles creating dataframe objects
import matplotlib.pyplot as plt # Used for plotting images, charts, graphs,...

# %%
df = pd.read_json('../Data/train.json')

df.head(20) # View first 20 items
# Out:
#         cuisine     id                                        ingredients
# 0         greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1   southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2      filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3        indian  22213                [water, vegetable oil, wheat, salt]
# 4        indian  13162  [black pepper, shallots, cornflour, cayenne pe...
# 5      jamaican   6602  [plain flour, sugar, butter, eggs, fresh ginge...
# 6       spanish  42779  [olive oil, salt, medium shrimp, pepper, garli...
# 7       italian   3735  [sugar, pistachio nuts, white almond bark, flo...
# 8       mexican  16903  [olive oil, purple onion, fresh pineapple, por...
# 9       italian  12734  [chopped tomatoes, fresh basil, garlic, extra-...
# 10      italian   5875  [pimentos, sweet pepper, dried oregano, olive ...
# 11      chinese  45887  [low sodium soy sauce, fresh ginger, dry musta...
# ...

# %%
df.shape

## This will print (rows, columns)
# Out:
# (39774, 3)

# %%
# So we see there are 39774 total recipes in the training data from above

df.columns
# Out:
# Index(['cuisine', 'id', 'ingredients'], dtype='object')

# %% [markdown]
# ### Cuisine Analysis
#
# <hr>

# %%
cuisines_distinct = df.cuisine.unique() # Returns array of unique values in 'cuisine' column
cuisines_distinct.sort()

print("Total number of distinct cuisines: %d\n" % len(cuisines_distinct))
for cuisine in cuisines_distinct:
    print(cuisine)
# Out:
# Total number of distinct cuisines: 20
#
# brazilian
# british
# cajun_creole
# chinese
# filipino
# french
# greek
# indian
# irish
# italian
# jamaican
# japanese
# korean
# mexican
# moroccan
# russian
# southern_us
# spanish
# thai
# vietnamese

# %%
cuisines_all = df['cuisine']
cuisines_all = list(cuisines_all)

# Test print cuisines_all just to make sure we're counting duplicates

for x in range(0,50):
    print(cuisines_all[x])
# Out:
# greek
# southern_us
# filipino
# indian
# indian
# jamaican
# spanish
# italian
# mexican
# italian
# italian
# chinese
# italian
# mexican
# italian
# indian
# british
# italian
# thai
# vietnamese
# thai
# mexican
# southern_us
# chinese
# italian
# chinese
# cajun_creole
# italian
# chinese
# mexican
# italian
# cajun_creole
# mexican
# thai
# italian
# cajun_creole
# italian
# filipino
# southern_us
# southern_us
# italian
# brazilian
# mexican
# indian
# mexican
# chinese
# french
# southern_us
# southern_us
# southern_us

# %%
hist_results = plt.hist(cuisines_all, 20)
plt.xticks(rotation=80)
plt.title('Cuisine Frequency')
plt.xlabel('Cuisine')
plt.show()

# %% [markdown]
# ### Ingredient Analysis
#
# <hr>

# %% [markdown]
# #### Let's try to get the ingredients out of individual lists, and combine them
# # into a single list where we can work with them better, and count how many there are.
#
# ingredients_all = {"abc"} # Was having trouble with set creation, doesn't like an empty set
#
# ingredientsByRecipe = df['ingredients']
#
# for recipe in ingredientsByRecipe:
#     for ingr in recipe:
#         ingredients_all.add(ingr)
#
# ingredients_distinct = list(ingredients_all)
# ingredients_distinct.sort()
#
# print('Total number of distinct ingredients: %d\n' % len(ingredients_distinct))
#
# for ingr in ingredients_distinct:
#     print(ingr)
#
# print(len(ingredients_distinct))

# %% [markdown]
# ### Experimental Code:
# <hr>

# %%
values = df.values # store the dataframe(table) into an array structure instead

for x in range(0,50): # let's look at the first 50 recipes
    print(values[x])
    print('\n')
# Out:
# ['greek' 10259
#  list(['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles'])]
#
#
# ['southern_us' 25693
#  list(['plain flour', 'ground pepper', 'salt', 'tomatoes', 'ground black pepper', 'thyme', 'eggs', 'green tomatoes', 'yellow corn meal', 'milk', 'vegetable oil'])]
#
#
# ['filipino' 20130
#  list(['eggs', 'pepper', 'salt', 'mayonaise', 'cooking oil', 'green chilies', 'grilled chicken breasts', 'garlic powder', 'yellow onion', 'soy sauce', 'butter', 'chicken livers'])]
#
#
# ['indian' 22213 list(['water', 'vegetable oil', 'wheat', 'salt'])]
#
#
# ['indian' 13162
#  list(['black pepper', 'shallots', 'cornflour', 'cayenne pepper', 'onions', 'garlic paste', 'milk', 'butter', 'salt', 'lemon juice', 'water', 'chili powder', 'passata', 'oil', 'ground cumin', 'boneless chicken skinless thigh', 'garam masala', 'double cream', 'natural yogurt', 'bay leaf'])]
#
#
# ['jamaican' 6602
# ...

# %% [raw]
# #Panda's Dummies

# %%
ingredients_all = {"abc"} 

ingredientsByRecipe = df['ingredients']

for recipe in ingredientsByRecipe:
    for ingr in recipe:
        ingredients_all.add(ingr)

ingredients_distinct = list(ingredients_all)
ingredients_distinct.sort()
# ingredients_distinct.insert(0, 'cuisine')
print('Total number of distinct ingredients: %d\n' % len(ingredients_distinct))

for ingr in ingredients_distinct:
    print(ingr)
    
print(len(ingredients_distinct))
# Out:
# Total number of distinct ingredients: 6715
#
# (    oz.) tomato sauce
# (   oz.) tomato paste
# (10 oz.) frozen chopped spinach
# (10 oz.) frozen chopped spinach, thawed and squeezed dry
# (14 oz.) sweetened condensed milk
# (14.5 oz.) diced tomatoes
# (15 oz.) refried beans
# 1% low-fat buttermilk
# 1% low-fat chocolate milk
# 1% low-fat cottage cheese
# 1% low-fat milk
# 2 1/2 to 3 lb. chicken, cut into serving pieces
# 2% low fat cheddar chees
# 2% low-fat cottage cheese
# 2% lowfat greek yogurt
# 2% milk shredded mozzarella cheese
# 2% reduced-fat milk
# 25% less sodium chicken broth
# 33% less sodium cooked deli ham
# 33% less sodium cooked ham
# 33% less sodium ham
# 33% less sodium smoked fully cooked ham
# 40% less sodium taco seasoning
# 40% less sodium taco seasoning mix
# 7 Up
# 8 ounc ziti pasta, cook and drain
# 95% lean ground beef
# A Taste of Thai Rice Noodles
# Accent Seasoning
# Adobo All Purpose Seasoning
# Alaskan king crab legs
# Alexia Waffle Fries
# ...

# %% [markdown]
# ## Creating an ingredient dictionary
#     This will allow for easier access to the data. Values provided are values that pd.factorize would give us when we input ingredient_distinct to the factorize pattern.

# %%
ingredient_dict = {}
count = 0;
for ingredient in ingredients_distinct:
    ingredient_dict[ingredient] = count
    count += 1

# %%
ingredient_dict
# Out:
# {'(    oz.) tomato sauce': 0,
#  '(   oz.) tomato paste': 1,
#  '(10 oz.) frozen chopped spinach': 2,
#  '(10 oz.) frozen chopped spinach, thawed and squeezed dry': 3,
#  '(14 oz.) sweetened condensed milk': 4,
#  '(14.5 oz.) diced tomatoes': 5,
#  '(15 oz.) refried beans': 6,
#  '1% low-fat buttermilk': 7,
#  '1% low-fat chocolate milk': 8,
#  '1% low-fat cottage cheese': 9,
#  '1% low-fat milk': 10,
#  '2 1/2 to 3 lb. chicken, cut into serving pieces': 11,
#  '2% low fat cheddar chees': 12,
#  '2% low-fat cottage cheese': 13,
#  '2% lowfat greek yogurt': 14,
#  '2% milk shredded mozzarella cheese': 15,
#  '2% reduced-fat milk': 16,
#  '25% less sodium chicken broth': 17,
#  '33% less sodium cooked deli ham': 18,
#  '33% less sodium cooked ham': 19,
#  '33% less sodium ham': 20,
#  '33% less sodium smoked fully cooked ham': 21,
#  '40% less sodium taco seasoning': 22,
#  '40% less sodium taco seasoning mix': 23,
#  '7 Up': 24,
#  '8 ounc ziti pasta, cook and drain': 25,
# ...

# %%
ingredient_table = pd.DataFrame(columns=[ingredients_distinct], dtype=np.int32)
ingredient_table.insert(0, 'cuisine', np.str,  allow_duplicates=True)

# %%
ingredient_table
ingredient_table.dtypes
# Out:
# cuisine                                                      object
# (    oz.) tomato sauce                                      float64
# (   oz.) tomato paste                                       float64
# (10 oz.) frozen chopped spinach                             float64
# (10 oz.) frozen chopped spinach, thawed and squeezed dry    float64
# (14 oz.) sweetened condensed milk                           float64
# (14.5 oz.) diced tomatoes                                   float64
# (15 oz.) refried beans                                      float64
# 1% low-fat buttermilk                                       float64
# 1% low-fat chocolate milk                                   float64
# 1% low-fat cottage cheese                                   float64
# 1% low-fat milk                                             float64
# 2 1/2 to 3 lb. chicken, cut into serving pieces             float64
# 2% low fat cheddar chees                                    float64
# ...

# %%
# for recipe in df.itertuples():
#     #print(recipe.ingredients , '\n')
#     newRow = []
#     newRow.append(recipe.cuisine)
#     for col in ingredient_table.columns:
#         if col in recipe.ingredients:
#             newRow.add(1)
#         else:
#             newRow.append(0)
#     newRow = pd.DataFrame(newRow)
#     ingredient_table = ingredient_table.append(newRow)

# %% [markdown]
# ### Experimental Code
#     Code is not intended to be used at this moment. Commented out due to it not fully working. Do not use and do not attempt to work on!

# %%
#for recipe in df.itertuples():
#    #print(recipe.ingredients , '\n')
#    newRow = []
#    newRow.append(recipe.cuisine)
#    for col in ingredient_table.columns:
#        if col in recipe.ingredients:
#            newRow.add(1)
#        else:
#            newRow.append(0)
#    newRow = pd.DataFrame(newRow)
#    ingredient_table = ingredient_table.append(newRow)

# %%
# newTab = []
# for recipe in df.itertuples():
#     newRow = []
#     newRow.append(recipe.cuisine)
#     for col in ingredients_distinct:
#         if col in recipe.ingredients:
#             newRow.append(1)
#         else:
#             newRow.append(0)
#     newTab = pd.DataFrame([newRow], columns=ingredient_table.columns)
#     ingredient_table = ingredient_table.append(newTab) #This line will make the table

# %% [markdown]
# # Creating a dictionary full of values
#     here I am constructing a hashtable with the key being our bought values id. I am then creating a 'hacked' way of creating an anonymous object in python. This will allow us to creat on the fly objects with the value of "cuisine" and the values of each list.

# %%
transformedDf_dict = {}
for recipe in df.itertuples(): 
    valueList = []
    for x in recipe.ingredients:
        valueList.append(ingredient_dict[x])
    transformedDf_dict[recipe.id] = type('Dummy', (object,), {"Cuisine":recipe.cuisine,"IngredientsValue": valueList})

# %%
#taking a look at our values from our dictionary
transformedDf_dict

#an example of how to pull data from our hashtable and access the object using a value from our data table
value = transformedDf_dict.get(20130)
print(value.Cuisine, value.IngredientsValue)
# Out:
# filipino [2437, 4570, 5310, 4032, 1941, 3091, 3125, 2903, 6677, 5745, 1221, 1532]
